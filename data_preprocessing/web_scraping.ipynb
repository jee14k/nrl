# %%
import os
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
import time

# Folder to save CSVs
SAVE_FOLDER = "nrl_stats_2025"

def ensure_folder(folder):
    if not os.path.exists(folder):
        os.makedirs(folder)
        print(f"Created folder: {folder}")

def get_last_column_name(driver):
    try:
        table = driver.find_element(By.CSS_SELECTOR, "table.table")
        headers = [th.text.strip() for th in table.find_elements(By.TAG_NAME, "th")]
        if headers:
            last_col = headers[-1].lower().replace(" ", "_")
            return last_col
    except Exception as e:
        print(f"Could not get last column name: {e}")
    return "stat"

def save_table_csv(driver, base_filename):
    try:
        table = driver.find_element(By.CSS_SELECTOR, "table.table")
        headers = [th.text.strip() for th in table.find_elements(By.TAG_NAME, "th")]

        rows = []
        for tr in table.find_elements(By.TAG_NAME, "tr"):
            cells = tr.find_elements(By.TAG_NAME, "td")
            if cells:
                rows.append([cell.text.strip() for cell in cells])

        if not rows:
            print(f"No data rows found in table for {base_filename}, skipping save.")
            return False

        df = pd.DataFrame(rows, columns=headers)

        # Build full path to save file inside folder
        filename = os.path.join(SAVE_FOLDER, base_filename + ".csv")
        counter = 1
        while os.path.exists(filename):
            filename = os.path.join(SAVE_FOLDER, f"{base_filename}_{counter}.csv")
            counter += 1

        df.to_csv(filename, index=False)
        print(f"Saved table to {filename}")
        return True
    except Exception as e:
        print(f"Failed to save table to {base_filename}.csv: {e}")
        return False

def main():
    ensure_folder(SAVE_FOLDER)

    driver = webdriver.Chrome()
    url = "https://www.nrl.com/stats/?competition=111&season=2025"
    driver.get(url)
    time.sleep(5)

    links = driver.find_elements(By.XPATH, "//a[contains(text(), 'View Full Table')]")

    stat_urls = []
    for link in links:
        href = link.get_attribute("href")
        if href and "stat=" in href:
            team_url = href.replace("/players/", "/teams/")
            stat_urls.append(team_url)

    print(f"✅ Found {len(stat_urls)} team stat table links")

    for stat_url in stat_urls:
        try:
            driver.get(stat_url)
            time.sleep(3)  # wait for page/table to load

            try:
                table = driver.find_element(By.CSS_SELECTOR, "table.table")
                headers = table.find_elements(By.TAG_NAME, "th")
                print(f"Headers found: {len(headers)}")
                if headers:
                    print("Headers:", [th.text for th in headers])

                rows = table.find_elements(By.TAG_NAME, "tr")
                data_rows = [row for row in rows if row.find_elements(By.TAG_NAME, "td")]
                print(f"Data rows found: {len(data_rows)}")

                if len(data_rows) == 0:
                    print(f"No data rows found on page: {stat_url}")
                    print("Table HTML snippet:\n", table.get_attribute('outerHTML')[:500])  # first 500 chars
                    continue  # skip saving for this URL

            except Exception as e:
                print(f"Error finding or reading table on page: {stat_url} | Exception: {e}")
                continue  # skip to next URL

            last_col = get_last_column_name(driver)
            base_filename = f"nrl_2025_{last_col}"

            success = save_table_csv(driver, base_filename)
            if not success:
                print(f"Skipping saving file for URL (no data): {stat_url}")

        except Exception as e:
            print(f"Error processing URL {stat_url}: {e}")

    driver.quit()

if __name__ == "__main__":
    main()
# Out:
# Created folder: nrl_stats_2025
# ✅ Found 37 team stat table links
# Headers found: 5
# Headers: ['', '', 'Team', 'Played', 'Points']
# Data rows found: 17
# Saved table to nrl_stats_2025\nrl_2025_points.csv
# Headers found: 5
# Headers: ['', '', 'Team', 'Played', 'Tries']
# Data rows found: 17
# Saved table to nrl_stats_2025\nrl_2025_tries.csv
# Headers found: 5
# Headers: ['', '', 'Team', 'Played', 'Goals']
# Data rows found: 17
# Saved table to nrl_stats_2025\nrl_2025_goals.csv
# Error finding or reading table on page: https://www.nrl.com/stats/teams/?competition=111&season=2025&stat=1000288 | Exception: Message: no such element: Unable to locate element: {"method":"css selector","selector":"table.table"}
#   (Session info: chrome=137.0.7151.105); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0x7ff7a7fecda5+78885]
# 	GetHandleVerifier [0x0x7ff7a7fece00+78976]
# 	(No symbol) [0x0x7ff7a7da9bca]
# 	(No symbol) [0x0x7ff7a7e00766]
# 	(No symbol) [0x0x7ff7a7e00a1c]
# 	(No symbol) [0x0x7ff7a7e54467]
# 	(No symbol) [0x0x7ff7a7e28bcf]
# 	(No symbol) [0x0x7ff7a7e5122f]
# 	(No symbol) [0x0x7ff7a7e28963]
# 	(No symbol) [0x0x7ff7a7df16b1]
# 	(No symbol) [0x0x7ff7a7df2443]
# 	GetHandleVerifier [0x0x7ff7a82c4eed+3061101]
# 	GetHandleVerifier [0x0x7ff7a82bf33d+3037629]
# 	GetHandleVerifier [0x0x7ff7a82de592+3165202]
# 	GetHandleVerifier [0x0x7ff7a800730e+186766]
# 	GetHandleVerifier [0x0x7ff7a800eb3f+217535]
# 	GetHandleVerifier [0x0x7ff7a7ff59b4+114740]
# 	GetHandleVerifier [0x0x7ff7a7ff5b69+115177]
# 	GetHandleVerifier [0x0x7ff7a7fdc368+10728]
# 	BaseThreadInitThunk [0x0x7ff8d345e8d7+23]
# 	RtlUserThreadStart [0x0x7ff8d4cfc34c+44]
#
# Error finding or reading table on page: https://www.nrl.com/stats/teams/?competition=111&season=2025&stat=1000287 | Exception: Message: no such element: Unable to locate element: {"method":"css selector","selector":"table.table"}
#   (Session info: chrome=137.0.7151.105); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0x7ff7a7fecda5+78885]
# 	GetHandleVerifier [0x0x7ff7a7fece00+78976]
# 	(No symbol) [0x0x7ff7a7da9bca]
# 	(No symbol) [0x0x7ff7a7e00766]
# 	(No symbol) [0x0x7ff7a7e00a1c]
# 	(No symbol) [0x0x7ff7a7e54467]
# 	(No symbol) [0x0x7ff7a7e28bcf]
# 	(No symbol) [0x0x7ff7a7e5122f]
# 	(No symbol) [0x0x7ff7a7e28963]
# 	(No symbol) [0x0x7ff7a7df16b1]
# 	(No symbol) [0x0x7ff7a7df2443]
# 	GetHandleVerifier [0x0x7ff7a82c4eed+3061101]
# 	GetHandleVerifier [0x0x7ff7a82bf33d+3037629]
# 	GetHandleVerifier [0x0x7ff7a82de592+3165202]
# 	GetHandleVerifier [0x0x7ff7a800730e+186766]
# 	GetHandleVerifier [0x0x7ff7a800eb3f+217535]
# 	GetHandleVerifier [0x0x7ff7a7ff59b4+114740]
# 	GetHandleVerifier [0x0x7ff7a7ff5b69+115177]
# 	GetHandleVerifier [0x0x7ff7a7fdc368+10728]
# 	BaseThreadInitThunk [0x0x7ff8d345e8d7+23]
# 	RtlUserThreadStart [0x0x7ff8d4cfc34c+44]
#
# Headers found: 5
# Headers: ['', '', 'Team', 'Played', 'Linebreaks']
# Data rows found: 17
# Saved table to nrl_stats_2025\nrl_2025_linebreaks.csv
# Headers found: 5
# Headers: ['', '', 'Team', 'Played', 'Post Contact Metres']
# Data rows found: 17
# Saved table to nrl_stats_2025\nrl_2025_post_contact_metres.csv
# Headers found: 5
# Headers: ['', '', 'Team', 'Played', 'Line Engaged']
# Data rows found: 17
# Saved table to nrl_stats_2025\nrl_2025_line_engaged.csv
# Headers found: 5
# Headers: ['', '', 'Team', 'Played', 'Tackle Breaks']
# Data rows found: 17
# Saved table to nrl_stats_2025\nrl_2025_tackle_breaks.csv
# Error finding or reading table on page: https://www.nrl.com/stats/teams/?competition=111&season=2025&stat=1000021 | Exception: Message: no such element: Unable to locate element: {"method":"css selector","selector":"table.table"}
#   (Session info: chrome=137.0.7151.105); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0x7ff7a7fecda5+78885]
# 	GetHandleVerifier [0x0x7ff7a7fece00+78976]
# 	(No symbol) [0x0x7ff7a7da9bca]
# 	(No symbol) [0x0x7ff7a7e00766]
# 	(No symbol) [0x0x7ff7a7e00a1c]
# 	(No symbol) [0x0x7ff7a7e54467]
# 	(No symbol) [0x0x7ff7a7e28bcf]
# 	(No symbol) [0x0x7ff7a7e5122f]
# 	(No symbol) [0x0x7ff7a7e28963]
# 	(No symbol) [0x0x7ff7a7df16b1]
# 	(No symbol) [0x0x7ff7a7df2443]
# 	GetHandleVerifier [0x0x7ff7a82c4eed+3061101]
# 	GetHandleVerifier [0x0x7ff7a82bf33d+3037629]
# 	GetHandleVerifier [0x0x7ff7a82de592+3165202]
# 	GetHandleVerifier [0x0x7ff7a800730e+186766]
# 	GetHandleVerifier [0x0x7ff7a800eb3f+217535]
# 	GetHandleVerifier [0x0x7ff7a7ff59b4+114740]
# 	GetHandleVerifier [0x0x7ff7a7ff5b69+115177]
# 	GetHandleVerifier [0x0x7ff7a7fdc368+10728]
# 	BaseThreadInitThunk [0x0x7ff8d345e8d7+23]
# 	RtlUserThreadStart [0x0x7ff8d4cfc34c+44]
#
# Headers found: 5
# Headers: ['', '', 'Team', 'Played', 'Try Assists']
# Data rows found: 17
# Saved table to nrl_stats_2025\nrl_2025_try_assists.csv
# Headers found: 5
# Headers: ['', '', 'Team', 'Played', 'Offloads']
# Data rows found: 17
# Saved table to nrl_stats_2025\nrl_2025_offloads.csv
# Headers found: 5
# Headers: ['', '', 'Team', 'Played', 'Line Break Assists']
# Data rows found: 17
# Saved table to nrl_stats_2025\nrl_2025_line_break_assists.csv
# Error finding or reading table on page: https://www.nrl.com/stats/teams/?competition=111&season=2025&stat=1000378 | Exception: Message: no such element: Unable to locate element: {"method":"css selector","selector":"table.table"}
#   (Session info: chrome=137.0.7151.105); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0x7ff7a7fecda5+78885]
# 	GetHandleVerifier [0x0x7ff7a7fece00+78976]
# 	(No symbol) [0x0x7ff7a7da9bca]
# 	(No symbol) [0x0x7ff7a7e00766]
# 	(No symbol) [0x0x7ff7a7e00a1c]
# 	(No symbol) [0x0x7ff7a7e54467]
# 	(No symbol) [0x0x7ff7a7e28bcf]
# 	(No symbol) [0x0x7ff7a7e5122f]
# 	(No symbol) [0x0x7ff7a7e28963]
# 	(No symbol) [0x0x7ff7a7df16b1]
# 	(No symbol) [0x0x7ff7a7df2443]
# 	GetHandleVerifier [0x0x7ff7a82c4eed+3061101]
# 	GetHandleVerifier [0x0x7ff7a82bf33d+3037629]
# 	GetHandleVerifier [0x0x7ff7a82de592+3165202]
# 	GetHandleVerifier [0x0x7ff7a800730e+186766]
# 	GetHandleVerifier [0x0x7ff7a800eb3f+217535]
# 	GetHandleVerifier [0x0x7ff7a7ff59b4+114740]
# 	GetHandleVerifier [0x0x7ff7a7ff5b69+115177]
# 	GetHandleVerifier [0x0x7ff7a7fdc368+10728]
# 	BaseThreadInitThunk [0x0x7ff8d345e8d7+23]
# 	RtlUserThreadStart [0x0x7ff8d4cfc34c+44]
#
# Headers found: 5
# Headers: ['', '', 'Team', 'Played', 'All Receipts']
# Data rows found: 17
# Saved table to nrl_stats_2025\nrl_2025_all_receipts.csv
# Headers found: 5
# Headers: ['', '', 'Team', 'Played', 'Conversion %']
# Data rows found: 17
# Saved table to nrl_stats_2025\nrl_2025_conversion_%.csv
# Headers found: 5
# Headers: ['', '', 'Team', 'Played', 'Total Kick Metres']
# Data rows found: 17
# Saved table to nrl_stats_2025\nrl_2025_total_kick_metres.csv
# Headers found: 5
# Headers: ['', '', 'Team', 'Played', 'Total Kicks']
# Data rows found: 17
# Saved table to nrl_stats_2025\nrl_2025_total_kicks.csv
# Headers found: 5
# Headers: ['', '', 'Team', 'Played', '40/20 Kicks']
# Data rows found: 10
# Failed to save table to nrl_2025_40/20_kicks.csv: Cannot save file into a non-existent directory: 'nrl_stats_2025\nrl_2025_40'
# Skipping saving file for URL (no data): https://www.nrl.com/stats/teams/?competition=111&season=2025&stat=82
# Error finding or reading table on page: https://www.nrl.com/stats/teams/?competition=111&season=2025&stat=1000299 | Exception: Message: no such element: Unable to locate element: {"method":"css selector","selector":"table.table"}
#   (Session info: chrome=137.0.7151.105); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0x7ff7a7fecda5+78885]
# 	GetHandleVerifier [0x0x7ff7a7fece00+78976]
# 	(No symbol) [0x0x7ff7a7da9bca]
# 	(No symbol) [0x0x7ff7a7e00766]
# 	(No symbol) [0x0x7ff7a7e00a1c]
# 	(No symbol) [0x0x7ff7a7e54467]
# 	(No symbol) [0x0x7ff7a7e28bcf]
# 	(No symbol) [0x0x7ff7a7e5122f]
# 	(No symbol) [0x0x7ff7a7e28963]
# 	(No symbol) [0x0x7ff7a7df16b1]
# 	(No symbol) [0x0x7ff7a7df2443]
# 	GetHandleVerifier [0x0x7ff7a82c4eed+3061101]
# 	GetHandleVerifier [0x0x7ff7a82bf33d+3037629]
# 	GetHandleVerifier [0x0x7ff7a82de592+3165202]
# 	GetHandleVerifier [0x0x7ff7a800730e+186766]
# 	GetHandleVerifier [0x0x7ff7a800eb3f+217535]
# 	GetHandleVerifier [0x0x7ff7a7ff59b4+114740]
# 	GetHandleVerifier [0x0x7ff7a7ff5b69+115177]
# 	GetHandleVerifier [0x0x7ff7a7fdc368+10728]
# 	BaseThreadInitThunk [0x0x7ff8d345e8d7+23]
# 	RtlUserThreadStart [0x0x7ff8d4cfc34c+44]
#
# Headers found: 5
# Headers: ['', '', 'Team', 'Played', 'Short Dropouts']
# Data rows found: 17
# Saved table to nrl_stats_2025\nrl_2025_short_dropouts.csv
# Headers found: 5
# Headers: ['', '', 'Team', 'Played', 'Tackles']
# Data rows found: 17
# Saved table to nrl_stats_2025\nrl_2025_tackles.csv
# Headers found: 5
# Headers: ['', '', 'Team', 'Played', 'Missed Tackles']
# Data rows found: 17
# Saved table to nrl_stats_2025\nrl_2025_missed_tackles.csv
# Headers found: 5
# Headers: ['', '', 'Team', 'Played', 'Charge Downs']
# Data rows found: 15
# Saved table to nrl_stats_2025\nrl_2025_charge_downs.csv
# Headers found: 5
# Headers: ['', '', 'Team', 'Played', 'Intercepts']
# Data rows found: 16
# Saved table to nrl_stats_2025\nrl_2025_intercepts.csv
# Headers found: 5
# Headers: ['', '', 'Team', 'Played', 'All Runs']
# Data rows found: 17
# Saved table to nrl_stats_2025\nrl_2025_all_runs.csv
# Headers found: 5
# Headers: ['', '', 'Team', 'Played', 'All Run Metres']
# Data rows found: 17
# Saved table to nrl_stats_2025\nrl_2025_all_run_metres.csv
# Headers found: 5
# Headers: ['', '', 'Team', 'Played', 'Dummy Half Runs']
# Data rows found: 17
# Saved table to nrl_stats_2025\nrl_2025_dummy_half_runs.csv
# Headers found: 5
# Headers: ['', '', 'Team', 'Played', 'Kick Return Metres']
# Data rows found: 17
# Saved table to nrl_stats_2025\nrl_2025_kick_return_metres.csv
# Headers found: 5
# Headers: ['', '', 'Team', 'Played', 'Errors']
# Data rows found: 17
# Saved table to nrl_stats_2025\nrl_2025_errors.csv
# Headers found: 5
# Headers: ['', '', 'Team', 'Played', 'Penalties Conceded']
# Data rows found: 17
# Saved table to nrl_stats_2025\nrl_2025_penalties_conceded.csv
# Headers found: 5
# Headers: ['', '', 'Team', 'Played', 'Handling Errors']
# Data rows found: 17
# Saved table to nrl_stats_2025\nrl_2025_handling_errors.csv
# Headers found: 5
# Headers: ['', '', 'Team', 'Played', 'Ineffective Tackles']
# Data rows found: 17
# Saved table to nrl_stats_2025\nrl_2025_ineffective_tackles.csv
# Error finding or reading table on page: https://www.nrl.com/stats/teams/?competition=111&season=2025&stat=1000283 | Exception: Message: no such element: Unable to locate element: {"method":"css selector","selector":"table.table"}
#   (Session info: chrome=137.0.7151.105); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0x7ff7a7fecda5+78885]
# 	GetHandleVerifier [0x0x7ff7a7fece00+78976]
# 	(No symbol) [0x0x7ff7a7da9bca]
# 	(No symbol) [0x0x7ff7a7e00766]
# 	(No symbol) [0x0x7ff7a7e00a1c]
# 	(No symbol) [0x0x7ff7a7e54467]
# 	(No symbol) [0x0x7ff7a7e28bcf]
# 	(No symbol) [0x0x7ff7a7e5122f]
# 	(No symbol) [0x0x7ff7a7e28963]
# 	(No symbol) [0x0x7ff7a7df16b1]
# 	(No symbol) [0x0x7ff7a7df2443]
# 	GetHandleVerifier [0x0x7ff7a82c4eed+3061101]
# 	GetHandleVerifier [0x0x7ff7a82bf33d+3037629]
# 	GetHandleVerifier [0x0x7ff7a82de592+3165202]
# 	GetHandleVerifier [0x0x7ff7a800730e+186766]
# 	GetHandleVerifier [0x0x7ff7a800eb3f+217535]
# 	GetHandleVerifier [0x0x7ff7a7ff59b4+114740]
# 	GetHandleVerifier [0x0x7ff7a7ff5b69+115177]
# 	GetHandleVerifier [0x0x7ff7a7fdc368+10728]
# 	BaseThreadInitThunk [0x0x7ff8d345e8d7+23]
# 	RtlUserThreadStart [0x0x7ff8d4cfc34c+44]
#
# Error finding or reading table on page: https://www.nrl.com/stats/teams/?competition=111&season=2025&stat=1000319 | Exception: Message: no such element: Unable to locate element: {"method":"css selector","selector":"table.table"}
#   (Session info: chrome=137.0.7151.105); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0x7ff7a7fecda5+78885]
# 	GetHandleVerifier [0x0x7ff7a7fece00+78976]
# 	(No symbol) [0x0x7ff7a7da9bca]
# 	(No symbol) [0x0x7ff7a7e00766]
# 	(No symbol) [0x0x7ff7a7e00a1c]
# 	(No symbol) [0x0x7ff7a7e54467]
# 	(No symbol) [0x0x7ff7a7e28bcf]
# 	(No symbol) [0x0x7ff7a7e5122f]
# 	(No symbol) [0x0x7ff7a7e28963]
# 	(No symbol) [0x0x7ff7a7df16b1]
# 	(No symbol) [0x0x7ff7a7df2443]
# 	GetHandleVerifier [0x0x7ff7a82c4eed+3061101]
# 	GetHandleVerifier [0x0x7ff7a82bf33d+3037629]
# 	GetHandleVerifier [0x0x7ff7a82de592+3165202]
# 	GetHandleVerifier [0x0x7ff7a800730e+186766]
# 	GetHandleVerifier [0x0x7ff7a800eb3f+217535]
# 	GetHandleVerifier [0x0x7ff7a7ff59b4+114740]
# 	GetHandleVerifier [0x0x7ff7a7ff5b69+115177]
# 	GetHandleVerifier [0x0x7ff7a7fdc368+10728]
# 	BaseThreadInitThunk [0x0x7ff8d345e8d7+23]
# 	RtlUserThreadStart [0x0x7ff8d4cfc34c+44]
#
# Headers found: 5
# Headers: ['', '', 'Team', 'Played', 'Supports']
# Data rows found: 17
# Saved table to nrl_stats_2025\nrl_2025_supports.csv
# Headers found: 5
# Headers: ['', '', 'Team', 'Played', 'Decoy Runs']
# Data rows found: 17
# Saved table to nrl_stats_2025\nrl_2025_decoy_runs.csv

# %%
import time
import os
import re
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd

# Step 0: Setup
TEAM_LIST_URL = "https://www.nrl.com/clubs/"
OUTPUT_FOLDER = "team_stats"
SAVE_CSV = os.path.join(OUTPUT_FOLDER, "nrl_2025_team_stats.csv")

def get_team_links(driver):
    driver.get(TEAM_LIST_URL)
    time.sleep(5)
    links = driver.find_elements(By.CSS_SELECTOR, "a[aria-label$='Club Profile']")
    return [link.get_attribute("href") for link in links]

def clean_value(val):
    """Strip % or 's' or whitespace from stat values"""
    return re.sub(r"[^\d\.]", "", val).strip()

def clean_key(key):
    """Convert 'Avg. Points Scored' to 'avg_points_scored'"""
    return re.sub(r"\s+|[^\w]", "_", key.lower()).strip("_")

def parse_team_stats(driver, team_url):
    driver.get(team_url)
    time.sleep(3)

    data = {}

    try:
        team_name = driver.title.split("|")[0].strip()
        data["team"] = team_name
    except:
        data["team"] = "Unknown"

    try:
        # Find all stat blocks
        stat_blocks = driver.find_elements(By.CSS_SELECTOR, "div.card-profile-stat")

        for block in stat_blocks:
            try:
                label = block.find_element(By.CSS_SELECTOR, "dt.card-profile-stat__name").text.strip()
                try:
                    value = block.find_element(By.CSS_SELECTOR, "dd.card-profile-stat__value").text.strip()
                except:
                    value = block.find_element(By.CSS_SELECTOR, "span.donut-chart-stat__value").text.strip()

                # Clean key and value
                data[clean_key(label)] = clean_value(value)
            except Exception as inner_e:
                print(f"⚠️ Skipped a stat block due to error: {inner_e}")
    except Exception as e:
        print(f"❌ Failed to extract stat blocks from: {team_url}\n{e}")

    return data

def main():
    # Create output folder if not exists
    os.makedirs(OUTPUT_FOLDER, exist_ok=True)

    driver = webdriver.Chrome()
    team_urls = get_team_links(driver)
    print(f"Found {len(team_urls)} teams.")

    all_stats = []
    for url in team_urls:
        print("→", url)
        stats = parse_team_stats(driver, url)
        print("   ", stats)
        all_stats.append(stats)

    driver.quit()

    # Save to CSV
    df = pd.DataFrame(all_stats)
    df.to_csv(SAVE_CSV, index=False)
    print(f"✅ Saved data to {SAVE_CSV}")

if __name__ == "__main__":
    main()
# Out:
# Found 17 teams.
# → https://www.nrl.com/clubs/brisbane-broncos/
#     {'team': 'Brisbane Broncos Club Profile', 'premierships': '6', 'minor_premierships': '4', 'runner_up': '1', 'total_wins': '537', 'total_losses': '370', 'win_percentage': '56', 'points_scored': '338', 'points_conceded': '294', 'completion_rate': '77', 'tackle_efficiency': '88.7', 'avg__points_scored': '26', 'avg__points_conceded': '22', 'avg__play_the_ball_speed': '3.59'}
# → https://www.nrl.com/clubs/canberra-raiders/
#     {'team': 'Canberra Raiders Club Profile', 'premierships': '3', 'minor_premierships': '1', 'runner_up': '3', 'total_wins': '546', 'total_losses': '504', 'win_percentage': '50', 'points_scored': '396', 'points_conceded': '300', 'completion_rate': '80', 'tackle_efficiency': '89.6', 'avg__points_scored': '28', 'avg__points_conceded': '21', 'avg__play_the_ball_speed': '3.47'}
# → https://www.nrl.com/clubs/canterbury-bankstown-bulldogs/
#     {'team': 'Canterbury-Bankstown Bulldogs Club Profile', 'premierships': '8', 'minor_premierships': '7', 'runner_up': '10', 'total_wins': '987', 'total_losses': '917', 'win_percentage': '49', 'points_scored': '330', 'points_conceded': '232', 'completion_rate': '79', 'tackle_efficiency': '87.6', 'avg__points_scored': '25', 'avg__points_conceded': '17', 'avg__play_the_ball_speed': '3.57'}
# → https://www.nrl.com/clubs/cronulla-sutherland-sharks/
#     {'team': 'Cronulla-Sutherland Sharks Club Profile', 'premierships': '1', 'minor_premierships': '2', 'runner_up': '3', 'total_wins': '681', 'total_losses': '684', 'win_percentage': '47', 'points_scored': '332', 'points_conceded': '306', 'completion_rate': '81', 'tackle_efficiency': '87.9', 'avg__points_scored': '23', 'avg__points_conceded': '21', 'avg__play_the_ball_speed': '3.55'}
# → https://www.nrl.com/clubs/dolphins/
#     {'team': 'The Dolphins Club Profile', 'premierships': '0', 'minor_premierships': '0', 'runner_up': '0', 'total_wins': '27', 'total_losses': '35', 'win_percentage': '43', 'points_scored': '408', 'points_conceded': '262', 'completion_rate': '78', 'tackle_efficiency': '89.1', 'avg__points_scored': '29', 'avg__points_conceded': '18', 'avg__play_the_ball_speed': '3.53'}
# → https://www.nrl.com/clubs/gold-coast-titans/
#     {'team': 'Gold Coast Titans Club Profile', 'premierships': '0', 'minor_premierships': '0', 'runner_up': '0', 'total_wins': '173', 'total_losses': '273', 'win_percentage': '37', 'points_scored': '268', 'points_conceded': '390', 'completion_rate': '79', 'tackle_efficiency': '86.5', 'avg__points_scored': '20', 'avg__points_conceded': '30', 'avg__play_the_ball_speed': '3.54'}
# → https://www.nrl.com/clubs/manly-warringah-sea-eagles/
#     {'team': 'Manly-Warringah Sea Eagles Club Profile', 'premierships': '8', 'minor_premierships': '9', 'runner_up': '11', 'total_wins': '983', 'total_losses': '725', 'win_percentage': '55', 'points_scored': '322', 'points_conceded': '300', 'completion_rate': '80', 'tackle_efficiency': '87.9', 'avg__points_scored': '23', 'avg__points_conceded': '21', 'avg__play_the_ball_speed': '3.64'}
# → https://www.nrl.com/clubs/melbourne-storm/
#     {'team': 'Melbourne Storm Club Profile', 'premierships': '4', 'minor_premierships': '6', 'runner_up': '5', 'total_wins': '481', 'total_losses': '234', 'win_percentage': '64', 'points_scored': '404', 'points_conceded': '233', 'completion_rate': '77', 'tackle_efficiency': '87.8', 'avg__points_scored': '33', 'avg__points_conceded': '19', 'avg__play_the_ball_speed': '3.56'}
# → https://www.nrl.com/clubs/newcastle-knights/
#     {'team': 'Newcastle Knights Club Profile', 'premierships': '2', 'minor_premierships': '0', 'runner_up': '0', 'total_wins': '426', 'total_losses': '470', 'win_percentage': '45', 'points_scored': '193', 'points_conceded': '262', 'completion_rate': '72', 'tackle_efficiency': '88', 'avg__points_scored': '13', 'avg__points_conceded': '18', 'avg__play_the_ball_speed': '3.51'}
# → https://www.nrl.com/clubs/north-queensland-cowboys/
#     {'team': 'North Queensland Cowboys Club Profile', 'premierships': '1', 'minor_premierships': '0', 'runner_up': '2', 'total_wins': '320', 'total_losses': '410', 'win_percentage': '42', 'points_scored': '278', 'points_conceded': '384', 'completion_rate': '75', 'tackle_efficiency': '87.1', 'avg__points_scored': '21', 'avg__points_conceded': '29', 'avg__play_the_ball_speed': '3.51'}
# → https://www.nrl.com/clubs/parramatta-eels/
#     {'team': 'Parramatta Eels Club Profile', 'premierships': '4', 'minor_premierships': '5', 'runner_up': '6', 'total_wins': '829', 'total_losses': '927', 'win_percentage': '45', 'points_scored': '231', 'points_conceded': '336', 'completion_rate': '77', 'tackle_efficiency': '87.6', 'avg__points_scored': '17', 'avg__points_conceded': '25', 'avg__play_the_ball_speed': '3.63'}
# → https://www.nrl.com/clubs/penrith-panthers/
#     {'team': 'Penrith Panthers Club Profile', 'premierships': '6', 'minor_premierships': '5', 'runner_up': '2', 'total_wins': '641', 'total_losses': '708', 'win_percentage': '45', 'points_scored': '286', 'points_conceded': '295', 'completion_rate': '79', 'tackle_efficiency': '88.5', 'avg__points_scored': '22', 'avg__points_conceded': '22', 'avg__play_the_ball_speed': '3.37'}
# → https://www.nrl.com/clubs/south-sydney-rabbitohs/
#     {'team': 'South Sydney Rabbitohs Club Profile', 'premierships': '21', 'minor_premierships': '17', 'runner_up': '14', 'total_wins': '1192', 'total_losses': '1057', 'win_percentage': '50', 'points_scored': '241', 'points_conceded': '329', 'completion_rate': '80', 'tackle_efficiency': '86.5', 'avg__points_scored': '17', 'avg__points_conceded': '23', 'avg__play_the_ball_speed': '3.55'}
# → https://www.nrl.com/clubs/st-george-illawarra-dragons/
#     {'team': 'St George Illawarra Dragons Club Profile', 'premierships': '1', 'minor_premierships': '2', 'runner_up': '1', 'total_wins': '319', 'total_losses': '337', 'win_percentage': '46', 'points_scored': '272', 'points_conceded': '331', 'completion_rate': '77', 'tackle_efficiency': '90.2', 'avg__points_scored': '20', 'avg__points_conceded': '25', 'avg__play_the_ball_speed': '3.51'}
# → https://www.nrl.com/clubs/sydney-roosters/
#     {'team': 'Sydney Roosters Club Profile', 'premierships': '15', 'minor_premierships': '20', 'runner_up': '15', 'total_wins': '1267', 'total_losses': '1033', 'win_percentage': '52', 'points_scored': '302', 'points_conceded': '320', 'completion_rate': '73', 'tackle_efficiency': '89.2', 'avg__points_scored': '23', 'avg__points_conceded': '24', 'avg__play_the_ball_speed': '3.47'}
# → https://www.nrl.com/clubs/warriors/
#     {'team': 'Warriors Club Profile', 'premierships': '0', 'minor_premierships': '1', 'runner_up': '2', 'total_wins': '330', 'total_losses': '386', 'win_percentage': '44', 'points_scored': '291', 'points_conceded': '256', 'completion_rate': '82', 'tackle_efficiency': '88.5', 'avg__points_scored': '22', 'avg__points_conceded': '19', 'avg__play_the_ball_speed': '3.52'}
# → https://www.nrl.com/clubs/wests-tigers/
#     {'team': 'Wests Tigers Club Profile', 'premierships': '1', 'minor_premierships': '0', 'runner_up': '0', 'total_wins': '249', 'total_losses': '371', 'win_percentage': '38', 'points_scored': '280', 'points_conceded': '346', 'completion_rate': '78', 'tackle_efficiency': '86.2', 'avg__points_scored': '20', 'avg__points_conceded': '24', 'avg__play_the_ball_speed': '3.55'}
# ✅ Saved data to output\nrl_2025_team_stats.csv
